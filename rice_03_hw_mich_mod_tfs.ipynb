# %% [markdown]
# ---
# title: Michelson Interferometers, Modulations, and Transfer Functions - Homework 03
# date: 2025-02-16
# authors:
#   - name: Professor Craig Cahillane
#     orcid: 0000-0002-3888-314X
#     affiliations:
#       - Syracuse University
# numbering:
#   heading_1: true
#   heading_2: true
#   heading_3: true
# ---

# %% [markdown]
# This is the third homework assignment for *Lasers and Optomechanics* at Syracuse University.\
# **It is due Monday, March 9th, 2026 by 5 pm**
#
# **<span style="color:#ff5555;">You will need to complete the questions in this jupyter notebook and submit it via `gitlab`</span>**

# %% [markdown]
# # Homodyne Michelson

# %% [markdown]
# ![homodyne-michelson-interferometer.jpeg](attachment:adbd6e8b-f2b7-44a4-8fe7-607a38f36e97.jpeg)
#
# Homodyne Michelson Interferometer Diagram
#
# ## Adjacency Matrix
# Set up an Adjacency Matrix $\boldsymbol{M}$ for the Homodyne Michelson.\
# You may choose any electric fields vector you want, but you have to include the explicitly labeled electric fields.\
# The homodyne angle $\phi_\mathrm{HD}$ can be considered as the total phase accrued by the local oscillator field $E_\mathrm{LO}$ in the pick-off path:
# \begin{align}
# E_\mathrm{LO} = -r_\mathrm{LO} e^{-i \phi_\mathrm{HD}} E_\mathrm{in}
# \end{align}
#
# ## Electric Field Transfer Functions
# Invert your Adjacency Matrix minus the identity $(\boldsymbol{M} - \boldsymbol{I})^{-1}$ to calculate the transfer functions from each electric field to every other electric field.\
# Pick out the field transfer functions from the input to the photodetectors $\mathrm{PD}_A$ and $\mathrm{PD}_B$ $\dfrac{E_\mathrm{PDA}}{E_\mathrm{in}}$ and
# $\dfrac{E_\mathrm{PDB}}{E_\mathrm{in}}$.
#
# ## Substitutions
# Apply the phase change of basis used in class $\phi_d = \dfrac{\phi_x - \phi_y}{2}$ and $\phi_c = \dfrac{\phi_x + \phi_y}{2}$ to your field transfer functions above.\
# You may also assume a perfect Michelson beamsplitter $r_\mathrm{BS} = t_\mathrm{BS} = \dfrac{1}{\sqrt{2}}$.
#
# ## Power Transfer Functions
# Calculate the input to power transfer functions $\dfrac{P_\mathrm{PDA}}{P_\mathrm{in}}$ and $\dfrac{P_\mathrm{PDB}}{P_\mathrm{in}}$.
#
# ## Interpretation
# How do $\dfrac{P_\mathrm{PDA}}{P_\mathrm{in}}$ and $\dfrac{P_\mathrm{PDB}}{P_\mathrm{in}}$ depend on the homodyne angle $\phi_\mathrm{HD}$, and the common and differential Michelson phase $\phi_d$ and $\phi_c$?\
# Can we manipulate the homodyne angle $\phi_\mathrm{HD}$ to detect the differential phase $\phi_d$?\
# Can you think of any problems you might run into if you tried to actually set up a homodyned Michelson?

# %% [markdown]
# ## <span style="color:rgb(255, 0, 200)">Question 1: Homodyne Michelson</span>
#
# **All of this work was done in a Mathematica notebook that has also been uploaded to my git; please see that document for further justification/derivations of the following answers**
#
# Directed graph to help me visualize and figure out the E fields:
#
# ![Screenshot 2026-03-10 at 10.16.04 AM.png](<attachment:Screenshot 2026-03-10 at 10.16.04 AM.png>)
#
# **1.1 Adjacency Matrix**
# $$\left(
# \begin{array}{c|ccccccccc}
#  & \text{Ein} & \text{EX1} & \text{EY1} & \text{EX2} & \text{EY2} & \text{EAS} & \text{ELO} & \text{EA} & \text{EB} \\
# \hline
# \text{Ein} & 0 & 0 & 0 & 0 & 0 & 0 & 0 & 0 & 0 \\
# \text{EX1} & e^{-ikL_x}t_{BS} & 0 & 0 & 0 & 0 & 0 & 0 & 0 & 0 \\
# \text{EY1} & -e^{-ikL_y}r_{BS} & 0 & 0 & 0 & 0 & 0 & 0 & 0 & 0 \\
# \text{EX2} & 0 & -e^{-ikL_x}r_x & 0 & 0 & 0 & 0 & 0 & 0 & 0 \\
# \text{EY2} & 0 & 0 & -e^{-ikL_y}r_y & 0 & 0 & 0 & 0 & 0 & 0 \\
# \text{EAS} & 0 & 0 & 0 & r_{BS} & t_{BS} & 0 & 0 & 0 & 0 \\
# \text{ELO} & -e^{-i\phi_{HD}}r_{LO} & 0 & 0 & 0 & 0 & 0 & 0 & 0 & 0 \\
# \text{EA} & 0 & 0 & 0 & 0 & 0 & t_{HD} & r_{HD} & 0 & 0 \\
# \text{EB} & 0 & 0 & 0 & 0 & 0 & -r_{HD} & t_{HD} & 0 & 0 \\
# \end{array}
# \right)$$
#
# **1.2 Electric Field Transfer Functions**
# TF Matrix:
#
# $$\left(
# \begin{array}{c|ccccccccc}
#  & \text{Ein} & \text{EX1} & \text{EY1} & \text{EX2} & \text{EY2} & \text{EAS} & \text{ELO} & \text{EA} & \text{EB} \\
# \hline
# \text{Ein} & 1 & 0 & 0 & 0 & 0 & 0 & 0 & 0 & 0 \\
# \text{EX1} & e^{-ikL_x}t_{BS} & 1 & 0 & 0 & 0 & 0 & 0 & 0 & 0 \\
# \text{EY1} & -e^{-ikL_y}r_{BS} & 0 & 1 & 0 & 0 & 0 & 0 & 0 & 0 \\
# \text{EX2} & -e^{-2ikL_x}r_x t_{BS} & -e^{-ikL_x}r_x & 0 & 1 & 0 & 0 & 0 & 0 & 0 \\
# \text{EY2} & e^{-2ikL_y}r_{BS}r_y & 0 & -e^{-ikL_y}r_y & 0 & 1 & 0 & 0 & 0 & 0 \\
# \text{EAS} & -e^{-2ikL_x}r_{BS}r_x t_{BS} + e^{-2ikL_y}r_{BS}r_y t_{BS} & -e^{-ikL_x}r_{BS}r_x & -e^{-ikL_y}r_y t_{BS} & r_{BS} & t_{BS} & 1 & 0 & 0 & 0 \\
# \text{ELO} & -e^{-i\phi_{HD}}r_{LO} & 0 & 0 & 0 & 0 & 0 & 1 & 0 & 0 \\
# \text{EA} & -e^{-i\phi_{HD}}r_{HD}r_{LO} - e^{-2ikL_x}r_{BS}r_x t_{BS}t_{HD} + e^{-2ikL_y}r_{BS}r_y t_{BS}t_{HD} & -e^{-ikL_x}r_{BS}r_x t_{HD} & -e^{-ikL_y}r_y t_{BS}t_{HD} & r_{BS}t_{HD} & t_{BS}t_{HD} & t_{HD} & r_{HD} & 1 & 0 \\
# \text{EB} & e^{-2ikL_x}r_{BS}r_{HD}r_x t_{BS} - e^{-2ikL_y}r_{BS}r_{HD}r_y t_{BS} - e^{-i\phi_{HD}}r_{LO}t_{HD} & e^{-ikL_x}r_{BS}r_{HD}r_x & e^{-ikL_y}r_{HD}r_y t_{BS} & -r_{BS}r_{HD} & -r_{HD}t_{BS} & -r_{HD} & t_{HD} & 0 & 1 \\
# \end{array}
# \right)$$
#
# TFs:
# $$\frac{E_{PDA}}{E_{in}} = -e^{-i\phi_{HD}}r_{HD}r_{LO} - e^{-2ikL_x}r_{BS}r_x t_{BS}t_{HD} + e^{-2ikL_y}r_{BS}r_y t_{BS}t_{HD}$$
#
# $$\frac{E_{PDB}}{E_{in}} = e^{-2ikL_x}r_{BS}r_{HD}r_x t_{BS} - e^{-2ikL_y}r_{BS}r_{HD}r_y t_{BS} - e^{-i\phi_{HD}}r_{LO}t_{HD}$$
#
# $$\frac{E_{as}}{E_{in}} = -e^{-2ikL_x}r_{BS}r_x t_{BS} + e^{-2ikL_y}r_{BS}r_y t_{BS}$$
#
# **1.3 Substitutions**
#
# $$\frac{E_{PDA}}{E_{in}} = \frac{1}{\sqrt{2}}\left(-e^{-i\phi_{HD}}r_{LO} + 2ie^{-2i\phi_c}\cos(\phi_d)\sin(\phi_d)\right)$$
#
# $$\frac{E_{PDB}}{E_{in}} = \frac{1}{2\sqrt{2}}\left(-e^{-2i(\phi_c - \phi_d)} + e^{-2i(\phi_c + \phi_d)} - 2e^{-i\phi_{HD}}r_{LO}\right)$$
#
# **1.4 Power Transfer Functions**
#
# $$\frac{P_{PDA}}{P_{in}} = \frac{1}{4}\left(1 + 2r_{LO}^2 - \cos(4\phi_d) - 4r_{LO}\sin(2\phi_d)\sin(2\phi_c - \phi_{HD})\right)$$
#
# $$\frac{P_{PDB}}{P_{in}} = \frac{1}{4}\left(1 + 2r_{LO}^2 - \cos(4\phi_d) + 4r_{LO}\sin(2\phi_d)\sin(2\phi_c - \phi_{HD})\right)$$

# %% [markdown]
# **1.5 Interpretation**
#
# Both the PDA and PDB have four terms; two DC terms (one of which comes from the LO path) and two terms that are dependent on the differential phase, common phase, and homodyne angle.
#
# For the cos(phi_d) term in both, when operating around the dark fringe phi_d = 0, this term goes to 1 and cancels with the first 1 in the paranthesis. Also, the last term goes to 0, so all thats left is the DC from the local oscillator; this makes sense, as no differential phase means that the only light incident on the PD's should be coming from the local oscillator.
#
# When the homodyne angle = phi_c, the last term goes to 0, but when the homodyne angle = 0,

# %% [markdown]
# # Asymmetric Michelson

# %% [markdown]
# Suppose you have a Michelson interferometer with the X-arm much longer than the Y-arm:
# $$L_x > L_y$$
# In this problem, we will calculate the full frequency response transfer functions of the Michelson
# $$\dfrac{P_\mathrm{as}}{\phi_\mathrm{CARM}}(\omega) \quad \mathrm{and} \quad
# \dfrac{P_\mathrm{as}}{\phi_\mathrm{DARM}}(\omega)$$
#
# I recommend using an algebra helper like *Mathematica* or *sympy* for this problem.
# You may convert your answers to LaTeX using *TeXform* in *Mathematica* or some such similar function for sympy.

# %% [markdown]
# ## Field tranfer functions
# Derive the electric field transfer functions for the following:
# \begin{align}
# \dfrac{E_\mathrm{x}}{E_\mathrm{in}}, \dfrac{E_\mathrm{y}}{E_\mathrm{in}}, \dfrac{E_\mathrm{as}}{E_\mathrm{in}}
# \end{align}
# where $E_\mathrm{in}$ is the input electric field $E_0 e^{i \omega_0 t}$,\
# $E_\mathrm{x}$ is the field *reflected from* the X-arm mirror,\
# $E_\mathrm{y}$ is the field *reflected from* the Y-arm mirror,\
# and $E_\mathrm{as}$ is the field at the antisymmetric (or transmission) port.
#
# Use $r_\mathrm{bs}, t_\mathrm{bs}$ for the beamsplitter reflection and transmission,\
# $r_\mathrm{x}, r_\mathrm{y}$ for the X and Y mirror reflections, and\
# $\phi_x, \phi_y$ for the single-pass phase accrued by the field as it propagates in the X-arm or Y-arm.

# %% [markdown]
# ## End Mirror Modulation
# Now, suppose we apply some common modulation to both end mirrors:
# $$\phi_c(t) = \phi_x(t) = \phi_y(t) = \Gamma \cos(\omega t)$$
# Write what the new arm reflected transfer functions are for:
# $$\dfrac{E_\mathrm{x}}{E_\mathrm{in}}, \dfrac{E_\mathrm{y}}{E_\mathrm{in}}$$
# *Hint: Remember that you should end up with three distinct fields at $\omega_0$ and $\omega_0 \pm \omega$*

# %% [markdown]
# ## Propagate to the antisymmetric port
# Propagate your new transfer functions to the antisymmetric port,
# and compute a new $\dfrac{E_\mathrm{as}}{E_\mathrm{in}}$.
#
# Be careful here.
# Consider carefully what $k = \omega/c$ is for each of your electric fields as they propagate back to the beamsplitter, accruing some phase $\phi = -k L$.\
# Should each field accrue the same phase?

# %% [markdown]
# ## Calculate the power response
# Calculate the power response to the common motion
# $\dfrac{P_\mathrm{as}}{P_\mathrm{in}}$.
#
# This is a lot of algebra, I recommend *Mathematica* or *sympy* to help you make sure you get things right here.\
# You may find it useful to express your arm phases in the common and differential bases again, since you have already incorporated the time-dependent term $\Gamma \cos(\omega t)$ as two additional sideband terms:
# $$\phi_x = \phi_c + \phi_d, \qquad \phi_y = \phi_c - \phi_d$$
#
# You may assume an ideal beamsplitter
# $$r_\mathrm{bs} = t_\mathrm{bs} = \dfrac{1}{\sqrt{2}}$$
# and balanced arms
# $$r_\mathrm{x} = t_\mathrm{y}$$
# and small modulation from the end mirrors
# $$\Gamma^2 \approx 0$$
#
# *Answer:*
# $$
# \dfrac{P_\mathrm{as}}{P_\mathrm{in}} = r_x^2 \left[
#   \sin^2(2 \phi_d) - 2 \Gamma \sin (4 \phi_d) \sin \left(\dfrac{\omega \phi_d}{\omega_0}\right) \sin     \left(\omega t+\frac{\omega \phi_c}{\omega_0}\right)
# \right]
# $$

# %% [markdown]
# ## Demodulate the power term
# Calculate
# $$P_\mathrm{as}^\mathrm{DC}, \, P_\mathrm{as}^I, \, P_\mathrm{as}^Q$$
# by integrating $P_\mathrm{as}$ over one cycle of $\omega t$ while multiplying by $1, \cos(\omega t)$ and $\sin(\omega t)$, respectively.
#
# Does your answer for $P_\mathrm{as}^\mathrm{DC}$ seem familiar?

# %% [markdown]
# ## Caluculate the Frequency Response to CARM motion in an Asymmetric Michelson
# Calculate the frequency response
# $$ P_\mathrm{as}(\omega) = P_\mathrm{as}^I(\omega) + i P_\mathrm{as}^Q(\omega)$$
# to CARM motion $\Gamma$.
#
# Plot the magnitude and phase for $\dfrac{P_\mathrm{as}}{\Gamma}(\omega)$.
#
# Assume
# \begin{align}
# r_x &= 1\\
# L_x &= 1000~\mathrm{m}\\
# L_y &= 1~\mathrm{m}\\
# \lambda &= 1064~\mathrm{nm}
# \end{align}

# %% [markdown]
# ## <span style="color:rgb(255, 0, 200)">Question 2: Asymmetric Michelson</span>
#
# This work was done entirely in a Mathematica notebook that has been uploaded to my git; please see the notebook for further justification and derivations of the following answers.
#
# Directed graph again for visualization:
#
# ![Screenshot 2026-03-10 at 11.06.31 AM.png](<attachment:Screenshot 2026-03-10 at 11.06.31 AM.png>)
#
# **2.1 Field Transfer Functions**
#
# Adjacency matrix:
#
# $$\left(
# \begin{array}{c|ccccc}
#  & \text{E\_in} & \text{E\_x} & \text{E\_y} & \text{E\_refl} & \text{E\_as} \\
# \hline
# \text{E\_in} & 0 & 0 & 0 & 0 & 0 \\
# \text{E\_x} & -e^{-2i\phi_x}r_x t_{BS} & 0 & 0 & 0 & 0 \\
# \text{E\_y} & e^{-2i\phi_y}r_{BS}r_y & 0 & 0 & 0 & 0 \\
# \text{E\_refl} & 0 & t_{BS} & -r_{BS} & 0 & 0 \\
# \text{E\_as} & 0 & r_{BS} & t_{BS} & 0 & 0 \\
# \end{array}
# \right)$$
#
# TF Matrix:
#
# $$\left(
# \begin{array}{c|ccccc}
#  & \text{E\_in} & \text{E\_x} & \text{E\_y} & \text{E\_refl} & \text{E\_as} \\
# \hline
# \text{E\_in} & 1 & 0 & 0 & 0 & 0 \\
# \text{E\_x} & -e^{-2i\phi_x}r_x t_{BS} & 1 & 0 & 0 & 0 \\
# \text{E\_y} & e^{-2i\phi_y}r_{BS}r_y & 0 & 1 & 0 & 0 \\
# \text{E\_refl} & -e^{-2i\phi_y}r_{BS}^2 r_y - e^{-2i\phi_x}r_x t_{BS}^2 & t_{BS} & -r_{BS} & 1 & 0 \\
# \text{E\_as} & -e^{-2i\phi_x}r_{BS}r_x t_{BS} + e^{-2i\phi_y}r_{BS}r_y t_{BS} & r_{BS} & t_{BS} & 0 & 1 \\
# \end{array}
# \right)$$
#
# TFs:
#
# $$\frac{E_x}{E_{in}} = -e^{-2i\phi_x}r_x t_{BS}$$
#
# $$\frac{E_y}{E_{in}} = e^{-2i\phi_y}r_{BS}r_y$$
#
# $$\frac{E_{as}}{E_{in}} = -e^{-2i\phi_x}r_{BS}r_x t_{BS} + e^{-2i\phi_y}r_{BS}r_y t_{BS}$$
#
# **2.2 End Mirror Modulation**
#
# $$\frac{E_x}{E_{in}} = -\frac{r_x}{\sqrt{2}}\left(
# J_0(2\Gamma)\, e^{i\omega_0 t - \frac{2iL_x\omega_0}{c}}
# - iJ_1(2\Gamma)\, e^{i(\omega_0-\omega)t - \frac{2iL_x(\omega_0-\omega)}{c}}
# - iJ_1(2\Gamma)\, e^{i(\omega_0+\omega)t - \frac{2iL_x(\omega_0+\omega)}{c}}
# \right)$$
#
# $$\frac{E_y}{E_{in}} = \frac{r_y}{\sqrt{2}}\left(
# J_0(2\Gamma)\, e^{i\omega_0 t - \frac{2iL_y\omega_0}{c}}
# - iJ_1(2\Gamma)\, e^{i(\omega_0+\omega)t - \frac{2iL_y(\omega_0+\omega)}{c}}
# - iJ_1(2\Gamma)\, e^{i(\omega_0-\omega)t - \frac{2iL_y(\omega_0-\omega)}{c}}
# \right)$$
#
# **2.3 Propagate to the antisymmetric port**
#
# $$\frac{E_{as}}{E_{in}} = \frac{1}{2}\left(
# - r_x J_0(2\Gamma)\, e^{i\omega_0 t - \frac{2iL_x\omega_0}{c}}
# + r_y J_0(2\Gamma)\, e^{i\omega_0 t - \frac{2iL_y\omega_0}{c}}
# + ir_x J_1(2\Gamma)\, e^{i(\omega_0+\omega)t - \frac{2iL_x(\omega_0+\omega)}{c}}
# - ir_y J_1(2\Gamma)\, e^{i(\omega_0+\omega)t - \frac{2iL_y(\omega_0+\omega)}{c}}
# + ir_x J_1(2\Gamma)\, e^{i(\omega_0-\omega)t - \frac{2iL_x(\omega_0-\omega)}{c}}
# - ir_y J_1(2\Gamma)\, e^{i(\omega_0-\omega)t - \frac{2iL_y(\omega_0-\omega)}{c}}
# \right)$$
#
# Plugging in substitutions $$\frac{L_x \omega_0}{c}=\phi_{x_0}, \frac{L_x (\omega_0+\omega)}{c}=\phi_{x_{upper}}, \frac{L_x (\omega_0-\omega)}{c}=\phi_{x_{lower}}, \frac{L_y \omega_0}{c}=\phi_{y_0}, \frac{L_y (\omega_0+\omega)}{c}=\phi_{y_{upper}}, \frac{L_y (\omega_0-\omega)}{c}=\phi_{y_{lower}}, r_x=r_y=r$$
#
# then gives
#
# $$\frac{E_{as}}{E_{in}} = \frac{1}{2}e^{-2i(\phi_c+\phi_d)+i\omega_0 t}\left(-1+e^{4i\phi_d}\right)r\left(J_0(2\Gamma) - 2iJ_1(2\Gamma)\cos(\omega t)\right)$$
#
# **2.4 Calculate the power response**
#
#
#
#
#
#
#
# **2.5 Demodulate the power term**
#
# **2.6 Calculate the frequency response to CARM motion in an Asymmetric Michelson**
